# %%
from __future__ import division
import numpy as np
import scipy as sp
import math
import pandas as pd
import ipympl
import matplotlib.pyplot as plt
from clustering import cluster_lab
from generate_data import gen_data
from pred_analysis import *
import init_dict
import scipy.stats as st
from cycler import cycler

# %%
df = pd.read_csv('convergence.csv')

# %%
df.head()
# Out:
#      m    n  k   p    L     G    r lda    u  init_fit    ...         minc  \
# 0  200  200  1  10  100  1000  0.2   5  0.5  0.536425    ...     0.000002
# 0  200  200  1  10  100  1000  0.2   5  0.5  0.536425    ...     0.000002
# 0  200  200  1  10  100  1000  0.2   5  0.5  0.536425    ...     0.000002
# 0  200  200  1  10  100  1000  0.2   5  0.5  0.536425    ...     0.000002
# 0  200  200  1  10  100  1000  0.2   5  0.5  0.536425    ...     0.000002
#
#        maxc  mink0  maxk0   avgk_0  mink1  maxk1   avgk_1  iter       fit
# 0  0.971753  0.442  0.772  0.62952  0.582  0.862  0.73036   0.0  0.536425
# 0  0.971753  0.442  0.772  0.62952  0.582  0.862  0.73036   1.0  0.592306
# 0  0.971753  0.442  0.772  0.62952  0.582  0.862  0.73036   2.0  0.663954
# 0  0.971753  0.442  0.772  0.62952  0.582  0.862  0.73036   3.0  0.703983
# 0  0.971753  0.442  0.772  0.62952  0.582  0.862  0.73036   4.0  0.747133
#
# [5 rows x 22 columns]

# %%
s = newdf[(newdf.lda==5)&(newdf.k==1)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $m=200$, $\lambda = 5$, $k=1$')

plt.figure()   
s = newdf[(newdf.lda==5)&(newdf.k==2)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
    
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $m=200$, $\lambda = 5$, $k=2$')

plt.figure()
s = newdf[(newdf.lda==5)&(newdf.k==5)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $m=200$, $\lambda = 5$, $k=5$')


plt.figure()
s = newdf[(newdf.lda==5)&(newdf.k==8)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $m=200$, $\lambda = 5$, $k=8$')

# %%
s = newdf[(newdf.lda==25)&(newdf.k==1)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $m=200$, $\lambda = 25$, $k=1$')

plt.figure()   
s = newdf[(newdf.lda==25)&(newdf.k==2)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
    
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $m=200$, $\lambda = 25$, $k=2$')

plt.figure()
s = newdf[(newdf.lda==25)&(newdf.k==5)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $m=200$, $\lambda = 25$, $k=5$')

plt.figure()
s = newdf[(newdf.lda==25)&(newdf.k==8)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $m=200$, $\lambda = 25$, $k=8$')

# %%
s = newdf[(newdf.lda==45)&(newdf.k==1)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $\lambda = 45$, $k=1$')

plt.figure()   
s = newdf[(newdf.lda==45)&(newdf.k==2)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
    
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $\lambda = 45$, $k=2$')

plt.figure()
s = newdf[(newdf.lda==45)&(newdf.k==5)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $\lambda = 45$, $k=5$')

plt.figure()
s = newdf[(newdf.lda==45)&(newdf.k==8)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $\lambda = 45$, $k=8$')

# %%
s = newdf[(newdf.lda==65)&(newdf.k==1)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $m=200$, $\lambda = 65$, $k=1$')

plt.figure()   
s = newdf[(newdf.lda==65)&(newdf.k==2)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
    
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $m=200$, $\lambda = 65$, $k=2$')

plt.figure()
s = newdf[(newdf.lda==65)&(newdf.k==5)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $m=200$, $\lambda = 65$, $k=5$')

plt.figure()
s = newdf[(newdf.lda==65)&(newdf.k==8)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $m=200$, $\lambda = 65$, $k=8$')

# %%
s = newdf[(newdf.lda==85)&(newdf.k==1)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $m=200$, $\lambda = 85$, $k=1$')

plt.figure()   
s = newdf[(newdf.lda==85)&(newdf.k==2)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
    
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $m=200$, $\lambda = 85$, $k=2$')

plt.figure()
s = newdf[(newdf.lda==85)&(newdf.k==5)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $m=200$, $\lambda = 85$, $k=5$')

plt.figure()
s = newdf[(newdf.lda==85)&(newdf.k==8)]
for i in s.index.values:
    plt.plot(s.loc[i].iter, s.loc[i].fit, marker='.')
plt.xlabel('Iteration')
plt.ylabel('Fit')
plt.title('Fixed $m=200$, $\lambda = 85$, $k=8$')
